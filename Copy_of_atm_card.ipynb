# %% [markdown]
# <a href="https://colab.research.google.com/github/dinesh842/Ldeploy/blob/main/Copy_of_atm_card.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time

print("Please insert Your CARD")

#for card processing
time.sleep(5)

password = 1234

#taking atm pin from user
pin = int(input("enter your atm pin "))

#user account balance
balance = 5000

#checking pin is valid or not 
if pin == password:
    #loop will run user get free 
    while True:

        #Showing  info to user

        print(""" 
			1 == balance
			2 == withdraw balance
			3 == deposit balance
			4 == exit
			"""
              )

        try:    
             #taking an option from user
            option = int(input("Please enter your choise "))
        except:
            print("Please enter valid option")
        
        #for option 1        
        if option == 1:
            print(f"Your current balance is {balance}")
                                     
        if option == 2:

            withdraw_amount = int(input("please enter withdraw_amount "))

            

            balance = balance - withdraw_amount

            print(f"{withdraw_amount} is debited from your account")

            

            print(f"your updated balance is {balance}")

            

        if option == 3:

            deposit_amount = int(input("please enter deposit_amount"))

            balance = balance + deposit_amount

            

            print(f"{deposit_amount} is credited to your account")



            print(f"your updated balance is {balance}")



        if option == 4:

            break


else:
    print("wrong pin Please try again")
# Out:
# Please insert Your CARD
# enter your atm pin 1234
#
# 			1 == balance
# 			2 == withdraw balance
# 			3 == deposit balance
# 			4 == exit
#
# Please enter your choise 2
# please enter withdraw_amount 7000
# 7000 is debited from your account
# your updated balance is -2000
#
# 			1 == balance
# 			2 == withdraw balance
# 			3 == deposit balance
# 			4 == exit
#
# Please enter your choise 1
# Your current balance is -2000
#
# 			1 == balance
# 			2 == withdraw balance
# 			3 == deposit balance
# 			4 == exit
#
# Please enter your choise 3
# please enter deposit_amount7000
# 7000 is credited to your account
# your updated balance is 5000
#
# 			1 == balance
# 			2 == withdraw balance
# 			3 == deposit balance
# 			4 == exit
#
# Please enter your choise 1
# Your current balance is 5000
#
# 			1 == balance
# 			2 == withdraw balance
# 			3 == deposit balance
# 			4 == exit
#
# Please enter your choise 3
# please enter deposit_amount6999
# 6999 is credited to your account
# ...
